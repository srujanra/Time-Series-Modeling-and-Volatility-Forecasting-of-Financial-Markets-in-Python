# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA as ARIMA
from scipy.stats.distributions import chi2
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
raw_csv_data = pd.read_csv("Index2018.csv") 
df_comp=raw_csv_data.copy()
df_comp.date = pd.to_datetime(df_comp.date, dayfirst = True)
df_comp.set_index("date", inplace=True)
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %%
df_comp['market_value']=df_comp.ftse

# %%
#del df_comp['spx']
#del df_comp['dax']
#del df_comp['ftse']
#del df_comp['nikkei']
size = int(len(df_comp)*0.8)
df, df_test = df_comp.iloc[:size], df_comp.iloc[size:]

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %%
df['returns'] = df.market_value.pct_change(1)*100

# %%
df['sq_returns'] = df.returns.mul(df.returns)

# %%
df.returns.plot(figsize=(20,5))
plt.title("Returns", size=24)
plt.show()

# %%
df.sq_returns.plot(figsize=(20,5))
plt.title("volatility", size=30)
plt.show()

# %%
sgt.plot_pacf(df.returns[1:],lags = 40, alpha= 0.05, zero = False, method = ('ols'))
plt.title("PACF OF Returns", size = 20)
plt.ylim(-0.1,0.05)
plt.show()

# %%
sgt.plot_pacf(df.sq_returns[1:],lags = 40, alpha= 0.05, zero = False, method = ('ols'))
plt.title("PACF OF Returns", size = 20)
plt.ylim(-0.1,0.3)
plt.show()

# %% [markdown]
# ## ARCH model

# %%
from arch import arch_model as arch

# %%
model_arch_1 = arch(df.returns[1:])
results_arch_1 = model_arch_1.fit(update_freq = 5)
results_arch_1.summary()
# Out:
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 7010.712887007633
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 6970.058478413694
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6970.058366189882
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -6970.06
# Distribution:                  Normal   AIC:                           13948.1
# Method:            Maximum Likelihood   BIC:                           13974.2
#                                         No. Observations:                 5020
# ...

# %% [markdown]
# ## simple arch(1)

# %%
model_arch_1 = arch(df.returns[1:],mean = "constant", vol = "ARCH", p = 1)
results_arch_1 = model_arch_1.fit(update_freq = 5)
results_arch_1.summary()
# Out:
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 7660.088782040875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7660.088782040875
#             Iterations: 6
#             Function evaluations: 33
#             Gradient evaluations: 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7660.09
# Distribution:                  Normal   AIC:                           15326.2
# Method:            Maximum Likelihood   BIC:                           15345.7
#                                         No. Observations:                 5020
# Date:                Sun, Mar 03 2024   Df Residuals:                     5019
# ...

# %% [markdown]
# Which is the most important argument we need to set in order to use an ARCH model?
#
# => vol

# %% [markdown]
# #### R-squared is a measurement of explanatory variation away form the mean, R-squared = 0

# %%
model_arch_1 = arch(df.returns[1:],mean = "AR", lags = [2,3,6], vol = "ARCH", p = 1, dist = "ged")
results_arch_1 = model_arch_1.fit(update_freq = 5)
results_arch_1.summary()
# Out:
# Iteration:      5,   Func. Count:     52,   Neg. LLF: 17359072.32600089
# Iteration:     10,   Func. Count:    100,   Neg. LLF: 7326.620524329802
# Iteration:     15,   Func. Count:    142,   Neg. LLF: 7317.121041781719
# Iteration:     20,   Func. Count:    186,   Neg. LLF: 7317.1181055234465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7317.118092656747
#             Iterations: 22
#             Function evaluations: 206
#             Gradient evaluations: 22
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  AR - ARCH Model Results
# ...
# Dep. Variable:                            returns   R-squared:                       0.008
# Mean Model:                                    AR   Adj. R-squared:                  0.007
# Vol Model:                                   ARCH   Log-Likelihood:               -7317.12
# Distribution:      Generalized Error Distribution   AIC:                           14648.2
# ...

# %% [markdown]
# ## higher-lag arch models

# %%
model_arch_2 = arch(df.returns[1:],mean = "constant", vol = "ARCH", p = 2)
results_arch_2 = model_arch_2.fit(update_freq = 5)
results_arch_2.summary()
# Out:
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 8810.02930517937
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7449.545164098316
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7449.55
# Distribution:                  Normal   AIC:                           14907.1
# Method:            Maximum Likelihood   BIC:                           14933.2
#                                         No. Observations:                 5020
# Date:                Sun, Mar 03 2024   Df Residuals:                     5019
# ...

# %%
model_arch_3 = arch(df.returns[1:],mean = "constant", vol = "ARCH", p = 3)
results_arch_3 = model_arch_3.fit(update_freq = 5)
results_arch_3.summary()
# Out:
# Iteration:      5,   Func. Count:     41,   Neg. LLF: 7496.4079308108885
# Iteration:     10,   Func. Count:     75,   Neg. LLF: 7277.050452148393
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7277.050452148393
#             Iterations: 11
#             Function evaluations: 80
#             Gradient evaluations: 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -7277.05
# Distribution:                  Normal   AIC:                           14564.1
# Method:            Maximum Likelihood   BIC:                           14596.7
#                                         No. Observations:                 5020
# ...

# %%
model_arch_12 = arch(df.returns[1:],mean = "constant", vol = "ARCH", p = 12)
results_arch_12 = model_arch_12.fit(update_freq = 5)
results_arch_12.summary()
# Out:
# Iteration:      5,   Func. Count:     86,   Neg. LLF: 9557.461547337656
# Iteration:     10,   Func. Count:    171,   Neg. LLF: 7694.2098482018655
# Iteration:     15,   Func. Count:    256,   Neg. LLF: 7343.845506915303
# Iteration:     20,   Func. Count:    340,   Neg. LLF: 7021.704568555548
# Iteration:     25,   Func. Count:    418,   Neg. LLF: 6988.513581773283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6988.513581773283
#             Iterations: 26
#             Function evaluations: 432
#             Gradient evaluations: 26
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -6988.51
# ...

# %%
model_arch_13 = arch(df.returns[1:],mean = "constant", vol = "ARCH", p = 13)
results_arch_13 = model_arch_13.fit(update_freq = 5)
results_arch_13.summary()
# Out:
# Iteration:      5,   Func. Count:     89,   Neg. LLF: 10011.775468928608
# Iteration:     10,   Func. Count:    179,   Neg. LLF: 7470.911405945963
# Iteration:     15,   Func. Count:    269,   Neg. LLF: 7087.90751318808
# Iteration:     20,   Func. Count:    359,   Neg. LLF: 7068.728949587957
# Iteration:     25,   Func. Count:    444,   Neg. LLF: 6984.175063695795
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6984.1750626174235
#             Iterations: 27
#             Function evaluations: 475
#             Gradient evaluations: 27
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ...
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -6984.18
# ...

# %% [markdown]
# alpha[9]	0.0292	1.603e-02	1.820	6.877e-02	[-2.245e-03,6.058e-02]
# ### ARCH(13) HAS A INSIGNIFICANT VALUE
